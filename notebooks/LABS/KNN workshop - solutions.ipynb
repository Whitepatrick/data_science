# %%
#load the digits dataset from sklearn
from sklearn.datasets import load_digits
import pandas as pd
# %matplotlib inline

# %%
digits = load_digits()

# %%
digits.keys()
# Out:
# ['images', 'data', 'target_names', 'DESCR', 'target']

# %% [markdown]
# ###### import test train split to split the data between training and testing

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, y_train, X_test, y_test = train_test_split??

# %%
X_train, y_train, X_test, y_test = train_test_split??

# %%
X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target)

# %% [markdown]
# ###### import the KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ###### Instantiate the classifier using only 1 neighbor

# %%
clf = KNeighborsClassifier(n_neighbors=2)

# %% [markdown]
# ###### Fit it on the training data

# %%
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=1, p=2, weights='uniform')

# %% [markdown]
# ###### Score it on the training set, and on the testing set. Do the results make sense

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
clf.score(X_test, y_test)
# Out:
# 0.99333333333333329

# %% [markdown]
# ###### Now loop through this process through neighbor #s up to 100, and plot the results. Which are the optimal # of neighbors?

# %%
results = []
for k in range(1,100):
    clf = KNeighborsClassifier(n_neighbors=k)
    clf.fit(X_train, y_train)
    results.append(clf.score(X_test,y_test))

# %%
pd.DataFrame(results).plot()

# %%
from scipy import stats
import numpy as np

# %%
stats.mode(np.array([5,5,1,2,3,3,4,4]),axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-e5a711aa74f9> in <module>()
# ----> 1 stats.mode(np.array([5,5,1,2,3,3,4,4]),axis=1)
#
# /usr/local/lib/python2.7/site-packages/scipy/stats/stats.pyc in mode(a, axis)
#     637     scores = np.unique(np.ravel(a))       # get ALL unique values
#     638     testshape = list(a.shape)
# --> 639     testshape[axis] = 1
#     640     oldmostfreq = np.zeros(testshape, dtype=a.dtype)
#     641     oldcounts = np.zeros(testshape, dtype=int)
#
# IndexError: list assignment index out of range

# %%
_y = digits.target.reshape(-1,1)

# %%
clf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=2, p=2, weights='uniform')

# %%
y_train
# Out:
# array([1, 1, 1, ..., 2, 8, 1])

# %%
dist, ind = clf.kneighbors(X_test)

# %%
z = y_train[ind]

# %%
z
# Out:
# array([[4, 1],
#        [6, 6],
#        [9, 9],
#        [5, 5],
#        [6, 6],
#        [7, 7],
#        [6, 6],
#        [4, 4],
#        [0, 0],
#        [8, 8],
#        [3, 3],
#        [2, 2],
#        [4, 4],
#        [7, 7],
#        [9, 9],
#        [7, 7],
#        [8, 8],
#        [9, 9],
#        [2, 2],
#        [5, 5],
#        [5, 5],
#        [3, 3],
#        [4, 4],
#        [6, 6],
#        [0, 0],
#        [0, 0],
#        [4, 4],
#        [5, 5],
#        [4, 4],
#        [6, 6],
#        [5, 5],
#        [6, 6],
#        [3, 3],
#        [4, 4],
#        [5, 5],
#        [0, 0],
#        [0, 0],
#        [3, 3],
#        [8, 8],
#        [6, 6],
#        [8, 8],
#        [1, 1],
#        [8, 8],
#        [4, 4],
#        [2, 2],
#        [7, 7],
#        [5, 5],
#        [3, 3],
#        [3, 3],
#        [0, 0],
#        [5, 5],
#        [4, 4],
#        [3, 3],
#        [7, 7],
#        [2, 2],
#        [6, 6],
#        [3, 3],
#        [2, 2],
#        [8, 8],
#        [4, 4],
#        [4, 4],
#        [3, 3],
#        [4, 4],
#        [1, 1],
#        [3, 3],
#        [4, 4],
#        [5, 5],
#        [1, 1],
#        [2, 2],
#        [8, 8],
#        [7, 7],
#        [1, 1],
#        [0, 0],
#        [9, 9],
#        [7, 7],
#        [2, 2],
#        [9, 9],
#        [7, 7],
#        [8, 8],
#        [0, 0],
#        [4, 4],
#        [0, 0],
#        [8, 8],
#        [5, 5],
#        [8, 8],
#        [7, 7],
#        [6, 6],
#        [9, 9],
#        [5, 5],
#        [4, 4],
#        [7, 7],
#        [6, 6],
#        [5, 5],
#        [4, 4],
#        [4, 1],
#        [8, 8],
#        [7, 7],
#        [3, 3],
#        [9, 9],
#        [0, 0],
#        [6, 6],
#        [9, 9],
#        [5, 5],
#        [7, 7],
#        [1, 1],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [5, 5],
#        [8, 8],
#        [4, 4],
#        [2, 2],
#        [8, 8],
#        [6, 6],
#        [8, 8],
#        [5, 5],
#        [1, 1],
#        [9, 9],
#        [2, 2],
#        [6, 6],
#        [5, 5],
#        [2, 2],
#        [6, 6],
#        [3, 3],
#        [2, 2],
#        [4, 4],
#        [0, 0],
#        [2, 2],
#        [8, 8],
#        [7, 7],
#        [9, 9],
#        [5, 5],
#        [6, 6],
#        [9, 9],
#        [6, 6],
#        [2, 2],
#        [5, 5],
#        [9, 9],
#        [1, 1],
#        [0, 0],
#        [1, 1],
#        [1, 1],
#        [7, 7],
#        [8, 8],
#        [2, 2],
#        [9, 9],
#        [7, 7],
#        [7, 7],
#        [2, 2],
#        [0, 0],
#        [4, 4],
#        [2, 2],
#        [0, 0],
#        [4, 4],
#        [9, 9],
#        [3, 3],
#        [1, 1],
#        [1, 1],
#        [6, 6],
#        [0, 0],
#        [4, 4],
#        [4, 4],
#        [4, 4],
#        [6, 6],
#        [4, 4],
#        [9, 9],
#        [8, 8],
#        [8, 8],
#        [5, 5],
#        [3, 3],
#        [2, 2],
#        [6, 6],
#        [5, 5],
#        [7, 7],
#        [0, 0],
#        [3, 3],
#        [5, 5],
#        [6, 6],
#        [1, 1],
#        [1, 1],
#        [3, 3],
#        [3, 3],
#        [1, 1],
#        [6, 6],
#        [6, 6],
#        [3, 3],
#        [0, 0],
#        [0, 0],
#        [9, 9],
#        [5, 5],
#        [2, 2],
#        [5, 5],
#        [1, 1],
#        [2, 2],
#        [8, 8],
#        [6, 6],
#        [3, 3],
#        [6, 6],
#        [4, 4],
#        [9, 9],
#        [5, 5],
#        [7, 7],
#        [7, 7],
#        [8, 8],
#        [1, 1],
#        [1, 1],
#        [0, 0],
#        [0, 0],
#        [4, 4],
#        [2, 2],
#        [6, 6],
#        [3, 3],
#        [0, 0],
#        [1, 1],
#        [6, 6],
#        [1, 1],
#        [3, 3],
#        [0, 0],
#        [5, 5],
#        [5, 5],
#        [2, 2],
#        [1, 1],
#        [4, 4],
#        [7, 7],
#        [4, 4],
#        [8, 8],
#        [5, 5],
#        [0, 0],
#        [8, 8],
#        [4, 4],
#        [6, 6],
#        [5, 5],
#        [1, 1],
#        [6, 6],
#        [9, 9],
#        [4, 4],
#        [9, 9],
#        [9, 9],
#        [7, 7],
#        [3, 3],
#        [5, 5],
#        [0, 0],
#        [1, 1],
#        [2, 2],
#        [2, 2],
#        [3, 3],
#        [5, 5],
#        [6, 6],
#        [0, 0],
#        [4, 4],
#        [4, 4],
#        [5, 5],
#        [8, 8],
#        [0, 0],
#        [7, 7],
#        [0, 0],
#        [3, 3],
#        [7, 7],
#        [1, 1],
#        [4, 4],
#        [7, 7],
#        [1, 1],
#        [2, 2],
#        [3, 3],
#        [4, 4],
#        [9, 9],
#        [8, 8],
#        [1, 1],
#        [9, 9],
#        [3, 8],
#        [5, 5],
#        [1, 1],
#        [6, 6],
#        [7, 7],
#        [8, 8],
#        [2, 2],
#        [2, 2],
#        [5, 5],
#        [5, 5],
#        [3, 3],
#        [2, 2],
#        [5, 5],
#        [7, 7],
#        [7, 7],
#        [8, 8],
#        [3, 3],
#        [5, 5],
#        [7, 7],
#        [1, 1],
#        [4, 4],
#        [4, 4],
#        [6, 6],
#        [3, 3],
#        [9, 9],
#        [2, 2],
#        [7, 7],
#        [9, 9],
#        [0, 0],
#        [1, 1],
#        [4, 4],
#        [3, 3],
#        [6, 6],
#        [3, 3],
#        [4, 4],
#        [9, 9],
#        [8, 8],
#        [9, 9],
#        [7, 7],
#        [1, 1],
#        [8, 6],
#        [3, 3],
#        [9, 9],
#        [8, 9],
#        [6, 6],
#        [8, 8],
#        [6, 6],
#        [1, 1],
#        [5, 5],
#        [7, 7],
#        [6, 6],
#        [9, 9],
#        [7, 7],
#        [6, 6],
#        [0, 0],
#        [5, 5],
#        [9, 9],
#        [8, 8],
#        [6, 6],
#        [8, 8],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [1, 1],
#        [6, 6],
#        [1, 1],
#        [3, 3],
#        [1, 1],
#        [8, 8],
#        [0, 0],
#        [8, 8],
#        [3, 3],
#        [6, 6],
#        [3, 3],
#        [3, 3],
#        [8, 8],
#        [8, 8],
#        [4, 4],
#        [6, 6],
#        [7, 7],
#        [3, 3],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [1, 1],
#        [1, 1],
#        [7, 7],
#        [9, 9],
#        [6, 6],
#        [0, 0],
#        [9, 9],
#        [9, 9],
#        [1, 1],
#        [2, 1],
#        [7, 7],
#        [5, 5],
#        [8, 8],
#        [9, 9],
#        [2, 8],
#        [3, 3],
#        [8, 8],
#        [5, 5],
#        [1, 1],
#        [2, 2],
#        [2, 2],
#        [6, 6],
#        [4, 4],
#        [4, 4],
#        [4, 4],
#        [6, 6],
#        [0, 0],
#        [4, 4],
#        [6, 6],
#        [5, 5],
#        [0, 0],
#        [6, 6],
#        [5, 5],
#        [3, 3],
#        [1, 1],
#        [6, 6],
#        [1, 1],
#        [9, 9],
#        [6, 6],
#        [5, 5],
#        [8, 8],
#        [7, 7],
#        [2, 2],
#        [0, 0],
#        [6, 6],
#        [6, 6],
#        [7, 7],
#        [6, 6],
#        [7, 7],
#        [9, 9],
#        [0, 0],
#        [5, 5],
#        [1, 1],
#        [4, 4],
#        [1, 1],
#        [9, 9],
#        [1, 1],
#        [2, 2],
#        [8, 8],
#        [1, 1],
#        [5, 5],
#        [4, 4],
#        [2, 2],
#        [7, 7],
#        [4, 4],
#        [6, 6],
#        [8, 8],
#        [6, 6],
#        [3, 3],
#        [3, 3],
#        [5, 5],
#        [4, 4],
#        [4, 4],
#        [4, 4],
#        [9, 9],
#        [0, 0],
#        [2, 2],
#        [8, 8],
#        [1, 1],
#        [2, 2],
#        [9, 9],
#        [0, 0],
#        [6, 6],
#        [9, 9],
#        [1, 1],
#        [5, 5],
#        [1, 1],
#        [3, 3],
#        [5, 5],
#        [1, 1],
#        [2, 2],
#        [3, 3],
#        [1, 1],
#        [0, 0],
#        [1, 1],
#        [3, 3]])

# %%
stats.mode(z,axis=1)
# Out:
# ModeResult(mode=array([[1],
#        [6],
#        [9],
#        [5],
#        [6],
#        [7],
#        [6],
#        [4],
#        [0],
#        [8],
#        [3],
#        [2],
#        [4],
#        [7],
#        [9],
#        [7],
#        [8],
#        [9],
#        [2],
#        [5],
#        [5],
#        [3],
#        [4],
#        [6],
#        [0],
#        [0],
#        [4],
#        [5],
#        [4],
#        [6],
#        [5],
#        [6],
#        [3],
#        [4],
#        [5],
#        [0],
#        [0],
#        [3],
#        [8],
#        [6],
#        [8],
#        [1],
#        [8],
#        [4],
#        [2],
#        [7],
#        [5],
#        [3],
#        [3],
#        [0],
#        [5],
#        [4],
#        [3],
#        [7],
#        [2],
#        [6],
#        [3],
#        [2],
#        [8],
#        [4],
#        [4],
#        [3],
#        [4],
#        [1],
#        [3],
#        [4],
#        [5],
#        [1],
#        [2],
#        [8],
#        [7],
#        [1],
#        [0],
#        [9],
#        [7],
#        [2],
#        [9],
#        [7],
#        [8],
#        [0],
#        [4],
#        [0],
#        [8],
#        [5],
#        [8],
#        [7],
#        [6],
#        [9],
#        [5],
#        [4],
#        [7],
#        [6],
#        [5],
#        [4],
#        [1],
#        [8],
#        [7],
#        [3],
#        [9],
#        [0],
#        [6],
#        [9],
#        [5],
#        [7],
#        [1],
#        [2],
#        [4],
#        [4],
#        [5],
#        [8],
#        [4],
#        [2],
#        [8],
#        [6],
#        [8],
#        [5],
#        [1],
#        [9],
#        [2],
#        [6],
#        [5],
#        [2],
#        [6],
#        [3],
#        [2],
#        [4],
#        [0],
#        [2],
#        [8],
#        [7],
#        [9],
#        [5],
#        [6],
#        [9],
#        [6],
#        [2],
#        [5],
#        [9],
#        [1],
#        [0],
#        [1],
#        [1],
#        [7],
#        [8],
#        [2],
#        [9],
#        [7],
#        [7],
#        [2],
#        [0],
#        [4],
#        [2],
#        [0],
#        [4],
#        [9],
#        [3],
#        [1],
#        [1],
#        [6],
#        [0],
#        [4],
#        [4],
#        [4],
#        [6],
#        [4],
#        [9],
#        [8],
#        [8],
#        [5],
#        [3],
#        [2],
#        [6],
#        [5],
#        [7],
#        [0],
#        [3],
#        [5],
#        [6],
#        [1],
#        [1],
#        [3],
#        [3],
#        [1],
#        [6],
#        [6],
#        [3],
#        [0],
#        [0],
#        [9],
#        [5],
#        [2],
#        [5],
#        [1],
#        [2],
#        [8],
#        [6],
#        [3],
#        [6],
#        [4],
#        [9],
#        [5],
#        [7],
#        [7],
#        [8],
#        [1],
#        [1],
#        [0],
#        [0],
#        [4],
#        [2],
#        [6],
#        [3],
#        [0],
#        [1],
#        [6],
#        [1],
#        [3],
#        [0],
#        [5],
#        [5],
#        [2],
#        [1],
#        [4],
#        [7],
#        [4],
#        [8],
#        [5],
#        [0],
#        [8],
#        [4],
#        [6],
#        [5],
#        [1],
#        [6],
#        [9],
#        [4],
#        [9],
#        [9],
#        [7],
#        [3],
#        [5],
#        [0],
#        [1],
#        [2],
#        [2],
#        [3],
#        [5],
#        [6],
#        [0],
#        [4],
#        [4],
#        [5],
#        [8],
#        [0],
#        [7],
#        [0],
#        [3],
#        [7],
#        [1],
#        [4],
#        [7],
#        [1],
#        [2],
#        [3],
#        [4],
#        [9],
#        [8],
#        [1],
#        [9],
#        [3],
#        [5],
#        [1],
#        [6],
#        [7],
#        [8],
#        [2],
#        [2],
#        [5],
#        [5],
#        [3],
#        [2],
#        [5],
#        [7],
#        [7],
#        [8],
#        [3],
#        [5],
#        [7],
#        [1],
#        [4],
#        [4],
#        [6],
#        [3],
#        [9],
#        [2],
#        [7],
#        [9],
#        [0],
#        [1],
#        [4],
#        [3],
#        [6],
#        [3],
#        [4],
#        [9],
#        [8],
#        [9],
#        [7],
#        [1],
#        [6],
#        [3],
#        [9],
#        [8],
#        [6],
#        [8],
#        [6],
#        [1],
#        [5],
#        [7],
#        [6],
#        [9],
#        [7],
#        [6],
#        [0],
#        [5],
#        [9],
#        [8],
#        [6],
#        [8],
#        [2],
#        [4],
#        [4],
#        [2],
#        [1],
#        [6],
#        [1],
#        [3],
#        [1],
#        [8],
#        [0],
#        [8],
#        [3],
#        [6],
#        [3],
#        [3],
#        [8],
#        [8],
#        [4],
#        [6],
#        [7],
#        [3],
#        [4],
#        [2],
#        [2],
#        [1],
#        [1],
#        [7],
#        [9],
#        [6],
#        [0],
#        [9],
#        [9],
#        [1],
#        [1],
#        [7],
#        [5],
#        [8],
#        [9],
#        [2],
#        [3],
#        [8],
#        [5],
#        [1],
#        [2],
#        [2],
#        [6],
#        [4],
#        [4],
#        [4],
#        [6],
#        [0],
#        [4],
#        [6],
#        [5],
#        [0],
#        [6],
#        [5],
#        [3],
#        [1],
#        [6],
#        [1],
#        [9],
#        [6],
#        [5],
#        [8],
#        [7],
#        [2],
#        [0],
#        [6],
#        [6],
#        [7],
#        [6],
#        [7],
#        [9],
#        [0],
#        [5],
#        [1],
#        [4],
#        [1],
#        [9],
#        [1],
#        [2],
#        [8],
#        [1],
#        [5],
#        [4],
#        [2],
#        [7],
#        [4],
#        [6],
#        [8],
#        [6],
#        [3],
#        [3],
#        [5],
#        [4],
#        [4],
#        [4],
#        [9],
#        [0],
#        [2],
#        [8],
#        [1],
#        [2],
#        [9],
#        [0],
#        [6],
#        [9],
#        [1],
#        [5],
#        [1],
#        [3],
#        [5],
#        [1],
#        [2],
#        [3],
#        [1],
#        [0],
#        [1],
#        [3]]), count=array([[1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2]]))
